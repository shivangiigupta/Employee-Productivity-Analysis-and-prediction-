# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ADDRESS OF THE CURRENT DIRECTORY

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shivangi'

# %% [markdown]
# IMPORTING THE FILES FROM THE DIRECTORY

# %%
os.chdir('C:\\Users\\shivangi\\documents')

# %%
os.listdir()
# Out:
# ['AMAZON SALES ANALYSIS.docx',
#  'aptitude.txt',
#  'Custom Office Templates',
#  'desktop.ini',
#  'introduction_to_sql_instruction_volume-1[1].docx',
#  'KingsoftData',
#  'Kulfi World Emp Data.csv',
#  'KULFI WORLD.csv',
#  'list.ipynb',
#  'My Data Sources',
#  'My Music',
#  'My Pictures',
#  'My Videos',
#  'OPERATOR ASSIGNMENT (1)-3 (5) (1).ipynb',
#  'Project outline submission.pdf',
#  'Shivangigupta_.docx',
#  'Shivangigupta_.pdf',
#  'SQL-Questions[1].docx',
#  '~$Data  Analysis and Algorithms[1].pptx',
#  '~$Data science principles.pptx',
#  '~$Database_for_Data_Science[1].pptx',
#  '~$Presentation[1].pptx',
#  '~$sign_of_Analysis_and_Algorithms_Notes[1].docx',
#  '~$STATISTICAL ANALYSIS AND PROBABILITY[1].pptx']

# %%
df=pd.read_csv( 'C:\\Users\\shivangi\\documents\\KULFI WORLD.csv ')

# %%
df
# Out:
#       Employee Id                  FullName Sex  Age EducationLevel HireMonth  \
# 0               1             saloni Kapoor   F   35        LEVEL 1      June
# 1               2  Shalabh Gautam             M   50        LEVEL 5   October
# 2               3  Govinda Dabral             M   34        LEVEL 3       May
# 3               4              Tanvi Sharma   F   31        LEVEL 2     March
# 4               5      Kedar                  M   39        LEVEL 2     April
# ...           ...                       ...  ..  ...            ...       ...
# 7710         7711          Udaya Tara Nayar   F   24        LEVEL 2     March
# 7711         7712              Mukesh Kumar   M   24        LEVEL 3   January
# 7712         7713    Saroj Chooramani Gopal   F   25        LEVEL 3    August
# 7713         7714              Ramji Sharma   M   24        LEVEL 1  February
# 7714         7715           Ambneesh Mishra   M   22        LEVEL 3      June
#
# ...

# %%
df.head(5)
# Out:
#    Employee Id                  FullName Sex  Age EducationLevel HireMonth  \
# 0            1             saloni Kapoor   F   35        LEVEL 1      June
# 1            2  Shalabh Gautam             M   50        LEVEL 5   October
# 2            3  Govinda Dabral             M   34        LEVEL 3       May
# 3            4              Tanvi Sharma   F   31        LEVEL 2     March
# 4            5      Kedar                  M   39        LEVEL 2     April
#
#   JobTitle DepartmentName  LengthService BusinessUnit Status TravelRequired  \
# 0    Baker         Bakery              6       Stores      T              N
# 1    Baker         Bakery              6       Stores      T              Y
# 2    Baker         Bakery              5       Stores      A              N
# 3    Baker         Bakery              6       Stores      A              N
# 4    Baker         Bakery              5       Stores      A              N
#
# ...

# %%
df.tail(2)
# Out:
#       Employee Id         FullName Sex  Age EducationLevel HireMonth  \
# 7713         7714     Ramji Sharma   M   24        LEVEL 1  February
# 7714         7715  Ambneesh Mishra   M   22        LEVEL 3      June
#
#           JobTitle    DepartmentName  LengthService BusinessUnit Status  \
# 7713  Dairy Person             Dairy              1       Stores      A
# 7714       Cashier  Customer Service              1       Stores      A
#
#      TravelRequired  PerformanceRating  JobSatisfaction  \
# 7713              N                  4                5
# 7714              N                  1                4
#
#       EmployeeAbsentismRate ProductivityRate NumberofteamChanged  AnnualRate  \
# 7713                     47              75%                   3      122358
# 7714                     11              80%                   2      113060
#
#       HourlyRate
# 7713          67
# 7714          61

# %%
df.shape
# Out:
# (7715, 19)

# %% [markdown]
# Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7715 entries, 0 to 7714
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee Id            7715 non-null   int64
#  1    FullName              6103 non-null   object
#  2   Sex                    7715 non-null   object
#  3   Age                    7715 non-null   int64
#  4   EducationLevel         7715 non-null   object
#  5   HireMonth              7715 non-null   object
#  6   JobTitle               7715 non-null   object
#  7   DepartmentName         7715 non-null   object
#  8   LengthService          7715 non-null   int64
#  9   BusinessUnit           7715 non-null   object
#  10  Status                 7715 non-null   object
#  11  TravelRequired         7715 non-null   object
#  12  PerformanceRating      7715 non-null   int64
#  13  JobSatisfaction        7715 non-null   int64
# ...

# %% [markdown]
# FINDING MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Employee Id                 0
#  FullName                1612
# Sex                         0
# Age                         0
# EducationLevel              0
# HireMonth                   0
# JobTitle                    0
# DepartmentName              0
# LengthService               0
# BusinessUnit                0
# Status                      0
# TravelRequired              0
# PerformanceRating           0
# JobSatisfaction             0
# EmployeeAbsentismRate       0
# ProductivityRate            0
# NumberofteamChanged         0
# AnnualRate                  0
# HourlyRate                  0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Employee Id               0.000000
#  FullName                20.894362
# Sex                       0.000000
# Age                       0.000000
# EducationLevel            0.000000
# HireMonth                 0.000000
# JobTitle                  0.000000
# DepartmentName            0.000000
# LengthService             0.000000
# BusinessUnit              0.000000
# Status                    0.000000
# TravelRequired            0.000000
# PerformanceRating         0.000000
# JobSatisfaction           0.000000
# EmployeeAbsentismRate     0.000000
# ProductivityRate          0.000000
# NumberofteamChanged       0.000000
# AnnualRate                0.000000
# HourlyRate                0.000000
# dtype: float64

# %%
df["NumberofteamChanged"]=df["NumberofteamChanged"].astype(str)
df["NumberofteamChanged"]=df["NumberofteamChanged"].apply(lambda x:x.replace('+',''))
df["NumberofteamChanged"]=df["NumberofteamChanged"].apply(lambda x:x.strip('+'))
df["NumberofteamChanged"]=df["NumberofteamChanged"].astype("int")

# %%
df["ProductivityRate"]=df["ProductivityRate"].astype(str)
df["ProductivityRate"]=df["ProductivityRate"].apply(lambda x:x.replace('%',''))
df["ProductivityRate"]=df["ProductivityRate"].apply(lambda x:x.strip('%'))
df["ProductivityRate"]=df["ProductivityRate"].astype("int")

# %%
df
# Out:
#       Employee Id                  FullName Sex  Age EducationLevel HireMonth  \
# 0               1             saloni Kapoor   F   35        LEVEL 1      June
# 1               2  Shalabh Gautam             M   50        LEVEL 5   October
# 2               3  Govinda Dabral             M   34        LEVEL 3       May
# 3               4              Tanvi Sharma   F   31        LEVEL 2     March
# 4               5      Kedar                  M   39        LEVEL 2     April
# ...           ...                       ...  ..  ...            ...       ...
# 7710         7711          Udaya Tara Nayar   F   24        LEVEL 2     March
# 7711         7712              Mukesh Kumar   M   24        LEVEL 3   January
# 7712         7713    Saroj Chooramani Gopal   F   25        LEVEL 3    August
# 7713         7714              Ramji Sharma   M   24        LEVEL 1  February
# 7714         7715           Ambneesh Mishra   M   22        LEVEL 3      June
#
# ...

# %%
df.describe()
# Out:
#        Employee Id          Age  LengthService  PerformanceRating  \
# count  7715.000000  7715.000000    7715.000000        7715.000000
# mean   3858.000000    39.785353       4.108231           2.945042
# std    2227.272996    10.997304       1.861368           1.409379
# min       1.000000    21.000000       0.000000           1.000000
# 25%    1929.500000    30.000000       3.000000           2.000000
# 50%    3858.000000    39.000000       4.000000           3.000000
# 75%    5786.500000    49.000000       5.000000           4.000000
# max    7715.000000    59.000000      12.000000           5.000000
#
#        JobSatisfaction  EmployeeAbsentismRate  ProductivityRate  \
# count      7715.000000            7715.000000       7715.000000
# mean          2.817369              61.470253         70.562929
# std           1.418043              48.882543         12.707016
# min           1.000000               0.000000         23.000000
# ...

# %% [markdown]
# DATA VISUALISATION

# %%
for i in ["Sex","JobTitle","DepartmentName","BusinessUnit"]:
    print("unique values of {} {}".format(i,df[i].value_counts()))
# Out:
# unique values of Sex M    3970
# F    3745
# Name: Sex, dtype: int64
# unique values of JobTitle Dairy Person                       1473
# Baker                              1403
# Training                           1370
# Cashier                            1287
# Produce Clerk                      1127
# Shelf Stocker                       661
# Bakery Manager                       45
# Store Manager                        39
# Customer Service Manager             34
# Processed Foods Manager              34
# Produce Manager                      34
# Beverages Manager                    34
# Accounting Clerk                     17
# Accounts Receiveable Clerk           15
# Accounts Payable Clerk               14
# Auditor                              14
# Trainer                              14
# HRIS Analyst                         13
# Recruiter                            13
# Benefits Admin                       11
# Labor Relations Analyst              11
# ...

# %%
df["LengthService"].value_counts()
# Out:
# 4     1757
# 5     1649
# 3     1158
# 6     1090
# 2      725
# 7      482
# 0      457
# 1      233
# 8      136
# 9       19
# 10       8
# 12       1
# Name: LengthService, dtype: int64

# %%
df.nunique()
# Out:
# Employee Id              7715
#  FullName                5382
# Sex                         2
# Age                        39
# EducationLevel              5
# HireMonth                  12
# JobTitle                   47
# DepartmentName             21
# LengthService              12
# BusinessUnit                2
# Status                      2
# TravelRequired              2
# PerformanceRating           5
# JobSatisfaction             5
# EmployeeAbsentismRate     232
# ProductivityRate           67
# NumberofteamChanged         4
# AnnualRate               7458
# HourlyRate                200
# dtype: int64

# %%
df["NumberofteamChanged"].unique()
# Out:
# array([3, 1, 0, 2])

# %%
df["NumberofteamChanged"].value_counts()
# Out:
# 3    2577
# 0    1930
# 1    1851
# 2    1357
# Name: NumberofteamChanged, dtype: int64

# %%
df["HireMonth"].value_counts()
# Out:
# May          679
# December     669
# March        666
# July         664
# August       663
# April        662
# November     659
# January      648
# June         633
# September    619
# October      615
# February     538
# Name: HireMonth, dtype: int64

# %%
pd.crosstab(df["Sex"],df["JobSatisfaction"])
# Out:
# JobSatisfaction    1     2    3    4    5
# Sex
# F                883   845  692  664  661
# M                920  1004  656  720  670

# %%
pd.crosstab(df["Sex"],df["PerformanceRating"])
# Out:
# PerformanceRating    1    2    3    4    5
# Sex
# F                  794  799  740  741  671
# M                  825  792  797  790  766

# %%
pd.crosstab(df["Status"],df["EducationLevel"])
# Out:
# EducationLevel  LEVEL 1  LEVEL 2  LEVEL 3  LEVEL 4  LEVEL 5
# Status
# A                  1389      851     1294      506      318
# T                  1109      664     1003      366      215

# %%
from matplotlib import pyplot
df.hist()
pyplot.show()

# %%
pd.plotting.scatter_matrix(df, diagonal="kde")
pyplot.show()

# %%
sns.countplot(x="Sex",data=df,palette="cool")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.set(style = 'darkgrid')

# %%
df.columns
# Out:
# Index(['Employee Id', ' FullName', 'Sex', 'Age', 'EducationLevel', 'HireMonth',
#        'JobTitle', 'DepartmentName', 'LengthService', 'BusinessUnit', 'Status',
#        'TravelRequired', 'PerformanceRating', 'JobSatisfaction',
#        'EmployeeAbsentismRate', 'ProductivityRate', 'NumberofteamChanged',
#        'AnnualRate', 'HourlyRate'],
#       dtype='object')

# %%
sns.boxplot(x=df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data_in=pd.DataFrame(df.groupby("HireMonth")[["ProductivityRate","PerformanceRating"]].mean())

# %%
data_in
# Out:
#            ProductivityRate  PerformanceRating
# HireMonth
# April             70.294562           2.987915
# August            70.542986           2.950226
# December          70.209268           2.961136
# February          69.905204           3.022305
# January           70.444444           2.938272
# July              70.772590           2.918675
# June              70.911532           2.947867
# March             70.980480           2.927928
# May               69.839470           2.885125
# November          71.165402           2.834598
# October           70.689431           3.029268
# September         70.945073           2.959612

# %%
new = sns.PairGrid(data_in)
new.map_diag(sns.histplot)
new.map_offdiag(sns.scatterplot)

# %%
a=df["JobSatisfaction"].value_counts()

# %%
a.plot(kind="pie",autopct="%.1f%%")
plt.legend(title="Job Satisfaction")
plt.show()

# %%
b=df["PerformanceRating"].value_counts()

# %%
b.plot(kind="pie",autopct="%.1f%%")
colors=["lightcyan","cyan","royalblue","darkblue","blue"]
plt.pie(a,colors=colors)
plt.show()

# %%
c=df["Status"].value_counts()

# %%
c.plot(kind="pie",fontsize=10,autopct="%.1f%%")
plt.show()

# %%
d=df["TravelRequired"].value_counts()

# %%
d.plot(kind="pie",autopct="%.1f%%")
plt.show()

# %%
new=df["PerformanceRating"].value_counts()
new.plot(kind="pie",autopct="%.1f%%")
plt.show()

# %%
sns.countplot(x="EducationLevel",data=df,palette="cool")
# Out:
# <AxesSubplot:xlabel='EducationLevel', ylabel='count'>

# %%
plt.figure(figsize=(12,4))

plt.hist(df.AnnualRate,color="darkgoldenrod",edgecolor="k",bins=100)
# Out:
# (array([1.320e+02, 9.070e+02, 1.229e+03, 1.028e+03, 9.490e+02, 7.270e+02,
#         6.170e+02, 4.300e+02, 3.150e+02, 3.010e+02, 2.270e+02, 1.770e+02,
#         1.440e+02, 9.600e+01, 1.020e+02, 5.900e+01, 4.800e+01, 4.400e+01,
#         3.000e+01, 1.400e+01, 1.600e+01, 1.300e+01, 1.500e+01, 1.800e+01,
#         5.000e+00, 1.000e+01, 5.000e+00, 1.400e+01, 4.000e+00, 5.000e+00,
#         4.000e+00, 5.000e+00, 3.000e+00, 5.000e+00, 2.000e+00, 3.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
plt.figure(figsize=(18,5))
plt.grid("teel",linestyle=":")
plt.hist(df["HourlyRate"],bins=100,color="maroon",edgecolor="yellow")
# Out:
# (array([7.900e+01, 7.140e+02, 1.167e+03, 1.095e+03, 9.920e+02, 7.530e+02,
#         6.740e+02, 4.690e+02, 3.380e+02, 3.290e+02, 2.300e+02, 1.830e+02,
#         1.460e+02, 1.050e+02, 9.000e+01, 7.000e+01, 4.000e+01, 4.800e+01,
#         3.000e+01, 1.800e+01, 1.800e+01, 1.600e+01, 1.400e+01, 1.500e+01,
#         1.000e+01, 7.000e+00, 9.000e+00, 1.100e+01, 5.000e+00, 6.000e+00,
#         4.000e+00, 5.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 2.000e+00,
#         3.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
g = sns.PairGrid(df, hue="Status")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
sns.displot(data=df, x="AnnualRate", col="Status", kde=True)

# %%
sns.displot(data=df, x="LengthService", col="Sex", kde=True)

# %%
sns.catplot(data=df, x="EducationLevel", y="LengthService", col="Sex", kind="bar")

# %%
sns.catplot( data=df, x="NumberofteamChanged", y="PerformanceRating", col="Sex", kind="bar", height=4, aspect=.6,)

# %%
sns.countplot(x=df["Status"])
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
sns.countplot(x=df["TravelRequired"])
# Out:
# <AxesSubplot:xlabel='TravelRequired', ylabel='count'>

# %%
sns.countplot(data=df, x="TravelRequired", hue="Sex")
# Out:
# <AxesSubplot:xlabel='TravelRequired', ylabel='count'>

# %%
sns.violinplot(x=df["HourlyRate"])
# Out:
# <AxesSubplot:xlabel='HourlyRate'>

# %%
sns.violinplot(data=df, x="HourlyRate", y="Sex")
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Sex'>

# %%
sns.boxplot(x=df["HourlyRate"])
# Out:
# <AxesSubplot:xlabel='HourlyRate'>

# %%
sns.catplot(data=df, x="Sex", y="AnnualRate", hue="Status", kind="bar",  palette="ch:.25")

# %%
corr =df.corr()

plt.figure(figsize=(12,6))
sns.heatmap(corr, annot = True, fmt='.1f', cmap = "crest")
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=df, kind="ecdf", x="NumberofteamChanged", col="EducationLevel", hue="TravelRequired", rug=True)

# %%
sns.relplot(data=df, x="HireMonth", y="ProductivityRate", hue="Sex", kind="line")

# %%
df = df[df['EmployeeAbsentismRate'] >200]

# %%
sns.boxplot(x=df["EmployeeAbsentismRate"])
# Out:
# <AxesSubplot:xlabel='EmployeeAbsentismRate'>

# %%
sns.boxplot(x=df["HourlyRate"])
# Out:
# <AxesSubplot:xlabel='HourlyRate'>

# %%
df=df[df["EmployeeAbsentismRate"]<200]
df=df[df["EmployeeAbsentismRate"]>20]
df=df[df["HourlyRate"]<85]
df=df[df["HourlyRate"]>14]
df=df[df["HourlyRate"]<85]
df=df[df["HourlyRate"]>14]

# %%
df.describe()
# Out:
#        Employee Id          Age  LengthService  PerformanceRating  \
# count  5156.000000  5156.000000    5156.000000        5156.000000
# mean   3831.730023    39.904383       4.110357           2.956168
# std    2229.819080    10.997768       1.848805           1.408034
# min       1.000000    21.000000       0.000000           1.000000
# 25%    1898.750000    31.000000       3.000000           2.000000
# 50%    3843.500000    39.000000       4.000000           3.000000
# 75%    5762.250000    49.000000       5.000000           4.000000
# max    7714.000000    59.000000      10.000000           5.000000
#
#        JobSatisfaction  EmployeeAbsentismRate  ProductivityRate  \
# count      5156.000000            5156.000000       5156.000000
# mean          2.810512              79.330489         70.735066
# std           1.419134              38.761373         12.609913
# min           1.000000              21.000000         23.000000
# ...

# %%
sns.boxplot(x=df["AnnualRate"])
# Out:
# <AxesSubplot:xlabel='AnnualRate'>

# %%
df=df.drop([" FullName","DepartmentName","BusinessUnit","Employee Id"], axis=1)

# %%
df
# Out:
#      Sex  Age EducationLevel HireMonth       JobTitle  LengthService Status  \
# 0      F   35        LEVEL 1      June          Baker              6      T
# 1      M   50        LEVEL 5   October          Baker              6      T
# 3      F   31        LEVEL 2     March          Baker              6      A
# 4      M   39        LEVEL 2     April          Baker              5      A
# 5      M   44        LEVEL 1      July          Baker              4      A
# ...   ..  ...            ...       ...            ...            ...    ...
# 7702   M   26        LEVEL 3      June   Dairy Person              3      T
# 7705   F   22        LEVEL 2      June        Cashier              1      A
# 7711   M   24        LEVEL 3   January  Shelf Stocker              4      A
# 7712   F   25        LEVEL 3    August  Shelf Stocker              3      A
# 7713   M   24        LEVEL 1  February   Dairy Person              1      A
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index Sex  Age EducationLevel HireMonth       JobTitle  LengthService  \
# 0         0   F   35        LEVEL 1      June          Baker              6
# 1         1   M   50        LEVEL 5   October          Baker              6
# 2         3   F   31        LEVEL 2     March          Baker              6
# 3         4   M   39        LEVEL 2     April          Baker              5
# 4         5   M   44        LEVEL 1      July          Baker              4
# ...     ...  ..  ...            ...       ...            ...            ...
# 5151   7702   M   26        LEVEL 3      June   Dairy Person              3
# 5152   7705   F   22        LEVEL 2      June        Cashier              1
# 5153   7711   M   24        LEVEL 3   January  Shelf Stocker              4
# 5154   7712   F   25        LEVEL 3    August  Shelf Stocker              3
# 5155   7713   M   24        LEVEL 1  February   Dairy Person              1
#
# ...

# %%
from scipy.stats import zscore

# %%
def log_transform(dfnew):
    return np.log(dfnew)

# %%
dfnew
# Out:
#       LengthService  PerformanceRating  JobSatisfaction  \
# 0                 6                  5                4
# 1                 6                  4                4
# 2                 5                  4                5
# 3                 6                  4                2
# 4                 5                  3                2
# ...             ...                ...              ...
# 7710              0                  4                1
# 7711              4                  3                1
# 7712              3                  1                2
# 7713              1                  4                5
# 7714              1                  1                4
#
#       EmployeeAbsentismRate  ProductivityRate  NumberofteamChanged  HourlyRate
# 0                        37                76                    3          22
# 1                        27                65                    3          59
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])

# %%
df
#1-Terminate
#0-Active
#0-Travel required no
#1-yes
# Out:
#       index  Sex  Age  EducationLevel  HireMonth  JobTitle  LengthService  \
# 0         0    0   14               0          6         4              6
# 1         1    1   29               4         10         4              6
# 2         2    0   10               1          7         4              6
# 3         3    1   18               1          0         4              5
# 4         4    1   23               0          5         4              4
# ...     ...  ...  ...             ...        ...       ...            ...
# 5151   5151    1    5               2          6        14              3
# 5152   5152    0    1               1          6         9              1
# 5153   5153    1    3               2          4        32              4
# 5154   5154    0    4               2          1        32              3
# 5155   5155    1    3               0          3        14              1
#
#       Status  TravelRequired  PerformanceRating  JobSatisfaction  \
# ...

# %%
df.shape
# Out:
# (5156, 16)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
x=df.drop("Status",1)

# %%
x.head()
# Out:
#    index  Sex  Age  EducationLevel  HireMonth  JobTitle  LengthService  \
# 0      0    0   14               0          6         4              6
# 1      1    1   29               4         10         4              6
# 2      2    0   10               1          7         4              6
# 3      3    1   18               1          0         4              5
# 4      4    1   23               0          5         4              4
#
#    TravelRequired  PerformanceRating  JobSatisfaction  EmployeeAbsentismRate  \
# 0               0                  4                3                     16
# 1               1                  3                3                      6
# 2               0                  3                1                      9
# 3               0                  2                1                     18
# 4               0                  1                4                      9
#
#    ProductivityRate  NumberofteamChanged  AnnualRate  HourlyRate
# ...

# %%
y=df["Status"]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Status, dtype: int32

# %% [markdown]
# Splitting the Training and testing dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (4124, 15) (4124,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (1032, 15) (1032,)

# %%
#scikit learn decision tree model training 
DT = DecisionTreeClassifier( )
DT = DT.fit(x_train, y_train)

# %%
DT.predict(x_test)
prediction = DT.predict(x_test)

# %%
prediction = DT.predict(x_test)
prediction
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       577
#            1       0.52      0.52      0.52       455
#
#     accuracy                           0.58      1032
#    macro avg       0.57      0.57      0.57      1032
# weighted avg       0.58      0.58      0.58      1032

# %%
DT.score(x_test, y_test)
# Out:
# 0.5765503875968992

# %%
#prediction
Y_pred = DT.predict(x_test)

# %%
print('Accuracy Score:', metrics.accuracy_score(y_test, Y_pred))
# Out:
# Accuracy Score: 0.5765503875968992

# %%
confusion_matrix(y_test,Y_pred)
# Out:
# array([[357, 220],
#        [217, 238]], dtype=int64)

# %%
#terminate=1
#active=0

# %%
rf = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
rf.score(x_train, y_train)
# Out:
# 0.9847235693501455

# %%
### Prediction for test data
pred = rf.predict(x_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.627906976744186

# %%
scoring="accuracy"

# %%
models=[]
models.append(("CART-DT",DecisionTreeClassifier()))
models.append(("SVM",SVC()))
models.append(("Naive Bayes", GaussianNB()))
models.append(("KNN",KNeighborsClassifier()))
models.append(("Random Forest",RandomForestClassifier()))


results=[]
names=[]

for name, model in models:
    kfold=KFold(n_splits=10)
    cv_results=cross_val_score(model, x_train, y_train, cv=kfold, scoring= scoring)
    results.append(cv_results)
    names.append(name)
    msg='For %s Model: Mean accuracy is %f ( std accuracy is %f )' %(name, cv_results.mean(),cv_results.std())
    print(msg)
# Out:
# For CART-DT Model: Mean accuracy is 0.578077 ( std accuracy is 0.023291 )
# For SVM Model: Mean accuracy is 0.617115 ( std accuracy is 0.030879 )
# For Naive Bayes Model: Mean accuracy is 0.580987 ( std accuracy is 0.028450 )
# For KNN Model: Mean accuracy is 0.594084 ( std accuracy is 0.017202 )
# For Random Forest Model: Mean accuracy is 0.606689 ( std accuracy is 0.026168 )

# %%
for name, model in models:
    model.fit(x_train,y_train)
    predictions= model.predict(x_test)
    print('/nModels: ',name)
    print("Accuracy Score: ", accuracy_score(y_test,predictions))
    print("Classification report : ", classification_report (y_test, predictions))
# Out:
# /nModels:  CART-DT
# Accuracy Score:  0.561046511627907
# Classification report :                precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       577
#            1       0.50      0.49      0.50       455
#
#     accuracy                           0.56      1032
#    macro avg       0.55      0.55      0.55      1032
# weighted avg       0.56      0.56      0.56      1032
#
# /nModels:  SVM
# Accuracy Score:  0.6337209302325582
# Classification report :                precision    recall  f1-score   support
#
#            0       0.69      0.64      0.66       577
#            1       0.58      0.63      0.60       455
#
#     accuracy                           0.63      1032
#    macro avg       0.63      0.63      0.63      1032
# weighted avg       0.64      0.63      0.63      1032
#
# /nModels:  Naive Bayes
# Accuracy Score:  0.5794573643410853
# Classification report :                precision    recall  f1-score   support
#
# ...

# %%
clf= SVC()
clf.fit(x_train,y_train)
accuracy= clf.score(x_test,y_test)
print("Test accuracy", accuracy)
# Out:
# Test accuracy 0.6337209302325582

# %%
predict=clf.predict(x_test)
predict
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
example_measure=[[1,0,5,3,5,7,98,56,76,1,3,2,2,1,2]]
prediction= clf.predict(example_measure)

print("1- Terminate, 0- Active", prediction)
# Out:
# 1- Terminate, 0- Active [0]

# %%
pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 1.3/1.3 MB 710.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 70.9/70.9 MB 1.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script lazypredict.exe is installed in 'C:\Users\shivangi\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import lazypredict

# %%
from lazypredict.Supervised import LazyClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2, random_state =123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric = None)

# %%
models,predictions = clf.fit(x_train, x_test, y_train, y_test)
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [00:19<00:00,  1.46it/s]
# [LightGBM] [Info] Number of positive: 1823, number of negative: 2301
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 937
# [LightGBM] [Info] Number of data points in the train set: 4124, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.442047 -> initscore=-0.232860
# [LightGBM] [Info] Start training from score -0.232860
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:19<00:00,  1.45it/s]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 0.64               0.64     0.64      0.64
# RandomForestClassifier             0.63               0.62     0.62      0.62
# XGBClassifier                      0.60               0.60     0.60      0.60
# LGBMClassifier                     0.60               0.60     0.60      0.60
# DecisionTreeClassifier             0.60               0.60     0.60      0.60
# BaggingClassifier                  0.60               0.59     0.59      0.60
# SVC                                0.59               0.59     0.59      0.59
# NearestCentroid                    0.59               0.58     0.58      0.59
# ExtraTreesClassifier               0.60               0.58     0.58      0.59
# QuadraticDiscriminantAnalysis      0.59               0.58     0.58      0.59
# NuSVC                              0.58               0.57     0.57      0.58
# ...

# %%
Dtree = DecisionTreeClassifier()
Dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
Dtree.predict(x_test)
prediction = Dtree.predict(x_test)
prediction = Dtree.predict(x_test)
prediction
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
# evaluation for multi class classification
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61       566
#            1       0.53      0.56      0.55       466
#
#     accuracy                           0.58      1032
#    macro avg       0.58      0.58      0.58      1032
# weighted avg       0.58      0.58      0.58      1032

# %%
Dtree.score(x_test, y_test)
# Out:
# 0.5813953488372093

# %%
rfc= RandomForestClassifier()
rfc.fit(x_train,y_train)
accuracy= clf.score(x_test,y_test)
print("Test accuracy", accuracy)
# Out:
# Test accuracy 0.6182170542635659

# %%
predict=clf.predict(x_test)

# %%
import pickle

# %%
pickle.dump(clf,open('KWSVC.pkl','wb'))
model=pickle.load(open('KWSVC.pkl','rb'))

print(model.predict([[1,1,0.1,2.2,3.3,0.2,3,1,1,1,2.2,3.4,0.1,3,2]]))
# Out:
# [0]

# %%
prediction=model.predict([[1,1,0.1,2.2,3.3,0.2,3,1,1,1,2.2,3.4,0.1,3,2]])

if (prediction[0] ==0):
    print("The person will be active ")
    
else:
    print("The person will be terminate")
# Out:
# The person will be active

# %%
print(model.predict([[1,1,0.1,2.2,3.3,0.2,3,1,1,1,2.2,3.4,0.1,3,2]]))
# Out:
# [0]

# %%
input_data=(1,1,0.1,2.2,3.3,0.2,3,1,1,1,2.2,3.4,0.1,3,2)
#changing the input data into numpy array
input_data_as_numpy_array=np.asarray(input_data)
#reshaping the array as we are predicting for one instance
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

prediction=model.predict(input_data_reshaped)
print(prediction)

if(prediction[0] ==0):
    print("The person will not be terminate")
else:
    print("The person will be terminate")
